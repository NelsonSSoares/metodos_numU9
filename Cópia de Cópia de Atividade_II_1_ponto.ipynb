# %% [markdown]
# # Introdução
# Esse exercício referece ao que foi visto nas aulas de coleções. A ideia aqui é permitir que os alunos possam apresentar conclusões sobre o resultado obtido. Os dados aqui utilizados serão gerados de maneira pseudoaleatórios, portanto cada execução terá um resultado único
# > obs: Execute em ordem para não haver problemas
# > links de referências:
# > [Coleções em python](https://phylos.net/2021-03-08/python-sequencias-e-colecoes#:~:text=Cole%C3%A7%C3%B5es%20s%C3%A3o%20conteineres%20de%20dados.%20No%20m%C3%B3dulo%20b%C3%A1sico,n%C3%A3o%20ordenada%20e%20n%C3%A3o%20indexada%2C%20sem%20membros%20duplicados.)

# %% [markdown]
# ## Perguntas de pesquisa e implementação
#
# > (Crie uma nova célula de texto ou escreva na célula de código abaixo)

# %% [markdown]
# ### Quais são as diferenças entre tupla e lista? Implemente um exemplo de cada um e apresente seus itens

# %%
# Uma lista pode ter seus valores alterados (Mutaveis) com metodos append() ou remove() e tambem são conhecidas por usar []
#Ex:

coordenadas = [-23.588254, -46.632477]

# Tuplas são imutaveis, são valores são sempre o mesmo (constantes) e tambem é conhecido por usar ()
#Ex:

coordenadas = (-23.588254, -46.632477)

# %% [markdown]
# ### Quais sãos as diferenças entre lista e dicionários em python? Implemente um exemplo simples de cada e apresente seus itens

# %%
#Listas e tuplas são acessadas atraves de um indice (index, i) conhecidas tambem por serem representadas com []
#Ex:
valor = ['Juarez','Nelson']
print(valor[0])
#Os Dicionarios são acessados por chaves, que geralmente são strings, conhecidas tambem por serem representadas com {}
#Ex:
valor1 = {'Nelson':'123deoliveira4', 'Juarez': '4deoliveira321'}
print(valor1['Nelson'])
# Out:
# Juarez
# 123deoliveira4

# %% [markdown]
# ### Em python o que significa quando um objeto é mutavel e imutavel? Quais são suas diferenças? Implemente ao menos um de cada na célula abaixo

# %%
#Mutaveis são variaveis/lista/dicionario que podem tem seus valores alterados
#Ex:
valor = ['Juarez','Nelson']
valor.append('Rebeca')
print(valor)

#Imutaveis são tuplas que depois de definidas não podem ter seu valor alterado
#Ex:
valor1 = ('Nelson','douglas')
##valor1.append('Rebeca')
print(valor1)
#por não existir constantes como em javascript ou final em java uma maneira de se declarar um valor constante
#é chamar uma função que retorna o valor constante desejado
#ex:
def const_pi():
    return 3.1415

print(const_pi())
# Out:
# ['Juarez', 'Nelson', 'Rebeca']
# ('Nelson', 'douglas')
# 3.1415

# %% [markdown]
# ## Exercício prático
# Um cliente solicitou a necessidade de conhecer melhor seu público e viu-se a necessidade de iniciar pela idade. Através da idade o cliente poderá mapear o perfil desse grupo, para isso temos que realizar algumas operações

# %% [markdown]
# ### Dados obtidos do cliente. A lista abaixo possui uma tupla com a idade e a somatória dos gastos em um determinado serviço

# %%
# SÓ EXECUTAR ESSA CÉLULA, NÃO PRECISA ALTERAR
# Importa biblioteca para usar números aleatórios
import random as numero_aleatorio # a palavra 'as' indica que queremos dar um apelido a essa biblioteca

# %% [markdown]
# Aqui será feito o preenchimento da lista com idade e gasto por idade (SÓ EXECUTAR)

# %%
# SÓ EXECUTAR ESSA CELULA, NÃO PRECISA ALTERAR
# Preenchimento da lista dos dados com números aleatórios. 
lista = []
for indice in range(1024):
  idade = numero_aleatorio.randint(18, 40) # Gera valores entre 18 e 40
  salario = numero_aleatorio.randint(2800, 10000) # Gera valores entre 2800 até 10000
  lista.append((idade, salario))
print(lista)
# Out:
# [(26, 5072), (24, 3079), (18, 8327), (31, 5020), (23, 4528), (28, 8650), (25, 6252), (33, 8389), (21, 6784), (22, 3361), (26, 4614), (38, 8483), (37, 8873), (28, 4612), (26, 3341), (29, 8786), (35, 9469), (29, 8875), (37, 8914), (39, 6287), (26, 5668), (33, 5680), (23, 6725), (22, 5620), (25, 8753), (20, 8636), (40, 7178), (31, 4151), (37, 3001), (19, 3131), (23, 2960), (23, 5841), (25, 5529), (18, 5039), (27, 8195), (37, 8602), (39, 9142), (38, 4002), (36, 9641), (30, 7187), (19, 9193), (19, 9785), (33, 6552), (35, 7035), (22, 6321), (23, 8866), (31, 3446), (24, 8699), (39, 7792), (33, 4795), (35, 6567), (18, 5190), (34, 5263), (36, 9483), (18, 9001), (29, 6387), (36, 2936), (20, 3777), (26, 8790), (33, 9746), (30, 5897), (24, 9606), (39, 6024), (36, 8709), (39, 6680), (29, 3560), (18, 6903), (24, 9317), (20, 3224), (25, 5432), (40, 6980), (36, 8340), (25, 6984), (35, 9296), (28, 3960), (32, 7873), (33, 5571), (24, 6363), (18, 5178), (20, 6701), (39, 9434), (34, 8711), (23, 9630), (
# ...

# %% [markdown]
# ### 1) Apresente o tipo e a quantidade de itens da variavel lista declarada e atribuida acima

# %%
# Preencha com sua resposta
print(len(lista))
print(type(lista))
# Out:
# 1024
# <class 'list'>

# %% [markdown]
# ### 2) Apresente a primeiro item e o último item da lista criada acima. Cada item dessa lista é uma tupla

# %%
# Preencha com sua resposta
print(lista[0])
print(lista[-1])
# Out:
# (25, 3574)
# (31, 8348)

# %% [markdown]
# ### 3) Apresente a soma dos cinco primeiros salários da lista criada acima

# %%
# Preencha com sua resposta
#result = lista[0][1] + lista[0][2] + lista[0][3] + lista[0][4] + lista[0][5]
#lista[0][1].head()
##lista[0][1].sum(5)

#for i in range(0,6):
#  result += lista[0][i]

#print(result)
result = 0
for pessoa in lista[0:5]:
  salario = pessoa[1]
  result = result + salario

print(result)
# Out:
# 26026

# %% [markdown]
# ### 4) Apresente a soma dos cinco últimos salários da lista acima

# %%
# Preencha com sua resposta

result = 0

for pessoa in lista[-5:]:
  salario = pessoa[1]
  result = result + salario

print(result)
# Out:
# 27668

# %% [markdown]
# ### 5) Faça a média das idades entre a posição 25 até 155 e apresente a média de seus salários em uma linha
#
# > Dica: use o print(f'') para formatar a saída dos resultados

# %%
# Preecha com sua resposta

soma = 0

for pessoa in lista[25:156]:
  soma += pessoa[1]

media = soma/(155 -25)
print(media)
# Out:
# 839174

# %% [markdown]
# ### 6) Dado a lista acima, faça os seguintes cálculos: (Obrigatório realizar com laço de repetição, sem usar funções de soma ou ajuda de bibliotecas externas)
#
# Faça a somatória das idades e realize a média com duas casas decimais arredondadas
# Faça a somatória dos gastos e realize a média com duas casas decimais truncadas

# %%
soma_idades = 0
soma_salarios = 0
quant_salarios = 0

for idade, salario in lista:
  soma_idades += idade
  soma_salarios += salario
  quant_salarios += 1

media_idades = round(soma_idades/len(lista), 2)
media_salarios = soma_salarios / quant_salarios

media_salarios = int(media_salarios * 100 )/ 100 

print(f"Soma das Idades: {soma_idades}")
print(f"Média das idades: {media_idades}")
# Out:
# Soma das Idades: 29760
# Média das idades: 29.06

# %%
# Média dos salários

print(f"Soma dos Salarios: {soma_salarios}")
print(f"Média dos Salarios: {media_salarios}")
# Out:
# Soma dos Salarios: 6466225
# Média dos Salarios: 6314.67

# %% [markdown]
# ### **ESCREVA AQUI A CONCLUSÃO**
#
# > obs: Escreva a sua conclusão dos resultados obtidos a cima. Lembre-se, apresentação em Data Science é tão importante quanto o algoritmo em sí

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Exercício de erros absoluto e relativos

# %% [markdown]
# ## Dado a lista acima, faça os seguintes cálculos de erros

# %%
# Erro real será dado por um número aleatório 
# (Cada execução dessa célula irá gerar um novo número)
erro_real = numero_aleatorio.uniform(18, 40)
print(erro_real)
# Out:
# 23.336405569716405

# %% [markdown]
# ### 1) Com base na média capturada com o exercício acima e o valor no erro_real, faça o cálculo do erro absoluto e erro relativo e apresente o resultado com conclusão.
#
# Fórmula do erro absoluto e relativo:
#
# Sendo $X$ o resultado real esperado e $X'$ o resultado aproximado obtido, logo:
#
# $Erro_{absoluto} = |X - X'| $
# $Erro_{relativo} = |X - X'| / |X'|$

# %%
# Faça o cálculo dos erros absolutos e relativos

error_abs = abs(media_idades - erro_real)
error_rel = (error_abs / media_idades)/ media_idades

print("Erro absoluto:", error_abs)
print("Erro Relativo:", error_rel)
# Out:
# Erro absoluto: 5.723594430283594
# Erro Relativo: 0.006777626504864741

# %% [markdown]
# ### ESCREVA AQUI A CONCLUSÃO (Dê dois cliques para editar)
